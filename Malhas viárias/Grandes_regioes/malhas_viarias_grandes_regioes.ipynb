# %%
from geobr import read_region

grandes_regioes = read_region(year=2010)
grandes_regioes.plot(edgecolor='white')
