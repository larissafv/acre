# %%
import matplotlib.pyplot as plt
import geopandas as gpd
# %matplotlib inline

# %%
estradas = gpd.read_file("C:\\Users\\Thiago\\Desktop\\Nova pasta2\\roads\\BRA_roads.shp")
fig, ax = plt.subplots(edgecolor='red', figsize=(15, 15), nrows=1, ncols=1)
estradas.plot(ax=ax, edgecolor='black', linewidth=1, linestyle='-')
ax.axis('off')
plt.title("Estradas")
fig.tight_layout()
