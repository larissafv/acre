# %%
import matplotlib.pyplot as plt
import geopandas as gpd
# %matplotlib inline

# %%
rodovias_estaduais = gpd.read_file("C:\\Users\\Thiago\\Desktop\\Nova pasta2\\estaduais\\RODOVIAS_ESTADUAIS_SRE2.shp")
fig, ax = plt.subplots(edgecolor='red', figsize=(15, 15), nrows=1, ncols=1)
rodovias_estaduais.plot(ax=ax, edgecolor='black', linewidth=1, linestyle='-')
ax.axis('off')
plt.title("Malha Rodoviária Estadual")
fig.tight_layout()
