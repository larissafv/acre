# %%
import matplotlib.pyplot as plt
import geopandas as gpd
# %matplotlib inline

# %%
rodovias_federais = gpd.read_file("C:\\Users\\Thiago\\Desktop\\Nova pasta2\\federais\\SNV_202001A.shp")
fig, ax = plt.subplots(edgecolor='red', figsize=(15, 15), nrows=1, ncols=1)
rodovias_federais.plot(ax=ax, edgecolor='black', linewidth=1, linestyle='-')
ax.axis('off')
plt.title("Malha Rodoviária Federal")
fig.tight_layout()
