# %%
from geobr import read_metro_area

regioes_metropolitanas = read_metro_area(year=2018)
regioes_metropolitanas.plot()
