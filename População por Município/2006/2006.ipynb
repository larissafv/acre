# %%
import geopandas as gpd
import pandas as pd
import matplotlib

# %%
pop06 = pd.read_csv("2006.csv",sep = ";")
pop06["Codmun6"] = pop06["COD_UF"]*10000 + pop06["COD_MN"]
pop06
# Out:
#      SIGLA_UF  COD_UF  COD_MN                  NOME_MN  POP_ESTIM  Codmun6
# 0          RO      11       1    Alta Floresta D'Oeste      29005   110001
# 1          RO      11      37  Alto Alegre dos Parecis      15454   110037
# 2          RO      11      40             Alto Paraíso      16510   110040
# 3          RO      11      34         Alvorada D'Oeste      19542   110034
# 4          RO      11       2                Ariquemes      86924   110002
# ...       ...     ...     ...                      ...        ...      ...
# 5559       GO      52    2200               Vianópolis      12950   522200
# 5560       GO      52    2205           Vicentinópolis       6591   522205
# 5561       GO      52    2220                 Vila Boa       3617   522220
# 5562       GO      52    2230            Vila Propício       5001   522230
# 5563       DF      53      10                 Brasília    2383784   530010
#
# [5564 rows x 6 columns]

# %%
br06 = gpd.read_file("shp/55mu2500pc.shp")
br06
# Out:
#       GEOCODIGO              NOME  UF  ID_UF        REGIAO  \
# 0       1200336       Mâncio Lima  AC     12         Norte
# 1       1300201  Atalaia do Norte  AM     13         Norte
# 2       1301654           Guajará  AM     13         Norte
# 3       1200427   Rodrigues Alves  AC     12         Norte
# 4       1200203   Cruzeiro do Sul  AC     12         Norte
# ...         ...               ...  ..    ...           ...
# 5802    3205309           Vitória  ES     32       Sudeste
# 5803    3205309           Vitória  ES     32       Sudeste
# 5804    3205309           Vitória  ES     32       Sudeste
# 5805    5003207           Corumbá  MS     50  Centro-Oeste
# 5806    5003306             Coxim  MS     50  Centro-Oeste
#
#                               MESOREGIAO       MICROREGIA LATITUDE LONGITUDE  \
# 0                          VALE DO JURUA  CRUZEIRO DO SUL   -7.614   -72.896
# 1                    SUDOESTE AMAZONENSE    ALTO SOLIMOES   -4.372   -70.192
# 2                    SUDOESTE AMAZONENSE            JURUA   -7.546   -72.584
# 3                          VALE DO JURUA  CRUZEIRO DO SUL   -7.742   -72.647
# 4                          VALE DO JURUA  CRUZEIRO DO SUL   -7.631    -72.67
# ...                                  ...              ...      ...       ...
# 5802           CENTRAL ESPIRITO-SANTENSE          VITORIA  -20.319   -40.338
# 5803           CENTRAL ESPIRITO-SANTENSE          VITORIA  -20.319   -40.338
# 5804           CENTRAL ESPIRITO-SANTENSE          VITORIA  -20.319   -40.338
# 5805         PANTANAL SUL MATO-GROSSENSE   BAIXO PANTANAL  -18.507   -54.760
# 5806  CENTRO NORTE DE MATO GROSSO DO SUL     ALTO TAQUARI  -19.009   -57.653
#
#      SEDE                                           geometry
# 0       t  POLYGON ((-2186731.448 -833173.486, -2179626.5...
# 1       t  POLYGON ((-2186731.448 -833173.486, -2186242.0...
# 2       t  POLYGON ((-2179626.522 -835548.916, -2176837.5...
# 3       t  POLYGON ((-2171301.929 -909411.712, -2169605.7...
# 4       t  POLYGON ((-2162938.083 -942180.645, -2140398.1...
# ...   ...                                                ...
# 5802    f  POLYGON ((2614287.231 -2466073.298, 2614455.88...
# 5803    f  POLYGON ((2614830.710 -2463981.134, 2614824.47...
# 5804    f  POLYGON ((2615205.653 -2464430.773, 2615324.99...
# 5805    T  POLYGON ((-389996.220 -2104237.792, -390679.18...
# 5806    T  POLYGON ((-138131.166 -2019041.609, -121307.29...
#
# [5807 rows x 11 columns]

# %%
trans_cod = pd.read_csv("cod00.csv", sep = ";")
br06 = br06.merge(trans_cod, on = "GEOCODIGO")
br06
# Out:
#       GEOCODIGO                 NOME  UF  ID_UF        REGIAO  \
# 0       1200336          Mâncio Lima  AC     12         Norte
# 1       1300201     Atalaia do Norte  AM     13         Norte
# 2       1301654              Guajará  AM     13         Norte
# 3       1200427      Rodrigues Alves  AC     12         Norte
# 4       1200203      Cruzeiro do Sul  AC     12         Norte
# ...         ...                  ...  ..    ...           ...
# 5802    2503209             Cabedelo  PB     25      Nordeste
# 5803    2503209             Cabedelo  PB     25      Nordeste
# 5804    2605459  Fernando de Noronha  PE     26      Nordeste
# 5805    5003207              Corumbá  MS     50  Centro-Oeste
# 5806    5003306                Coxim  MS     50  Centro-Oeste
#
#                               MESOREGIAO           MICROREGIA LATITUDE  \
# 0                          VALE DO JURUA      CRUZEIRO DO SUL   -7.614
# 1                    SUDOESTE AMAZONENSE        ALTO SOLIMOES   -4.372
# 2                    SUDOESTE AMAZONENSE                JURUA   -7.546
# 3                          VALE DO JURUA      CRUZEIRO DO SUL   -7.742
# 4                          VALE DO JURUA      CRUZEIRO DO SUL   -7.631
# ...                                  ...                  ...      ...
# 5802                      MATA PARAIBANA          JOAO PESSOA   -6.981
# 5803                      MATA PARAIBANA          JOAO PESSOA   -6.981
# 5804             METROPOLITANA DE RECIFE  FERNANDO DE NORONHA    -3.84
# 5805         PANTANAL SUL MATO-GROSSENSE       BAIXO PANTANAL  -18.507
# 5806  CENTRO NORTE DE MATO GROSSO DO SUL         ALTO TAQUARI  -19.009
#
#      LONGITUDE SEDE                                           geometry   ANO  \
# 0      -72.896    t  POLYGON ((-2186731.448 -833173.486, -2179626.5...  2000
# 1      -70.192    t  POLYGON ((-2186731.448 -833173.486, -2186242.0...  2000
# 2      -72.584    t  POLYGON ((-2179626.522 -835548.916, -2176837.5...  2000
# 3      -72.647    t  POLYGON ((-2171301.929 -909411.712, -2169605.7...  2000
# 4       -72.67    t  POLYGON ((-2162938.083 -942180.645, -2140398.1...  2000
# ...        ...  ...                                                ...   ...
# 5802   -34.834    t  POLYGON ((2113455.478 -823811.979, 2114256.881...  2000
# 5803   -34.834    f  POLYGON ((2113988.638 -814803.669, 2114603.431...  2000
# 5804   -32.411    t  POLYGON ((2399722.674 -456254.086, 2399236.061...  2000
# 5805   -54.760    T  POLYGON ((-389996.220 -2104237.792, -390679.18...  2000
# 5806   -57.653    T  POLYGON ((-138131.166 -2019041.609, -121307.29...  2000
#
#       Codmun6
# 0      120033
# 1      130020
# 2      130165
# 3      120042
# 4      120020
# ...       ...
# 5802   250320
# 5803   250320
# 5804   260545
# 5805   500320
# 5806   500330
#
# [5807 rows x 13 columns]

# %%
mapa = br06.merge(pop06, on = "Codmun6")
mapa.plot(column = "POP_ESTIM", figsize = (20,20), 
          legend = True, legend_kwds={'label': "População Estimada em 2006", 'orientation': "horizontal"})
